# %% [markdown]
# ## Import packages:

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
import nltk
import gensim
import re
import unicodedata
import datetime
import collections
import random
import time
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from matplotlib import pylab
from gensim.models.phrases import Phraser
from gensim.models import Phrases
from sklearn.manifold import TSNE
import treetaggerwrapper
import string
import os
import platform
treetaggerPath = str(os.getcwd()) + "/treetagger/" + str(platform.system()) + "/"

# %%
treetaggerPath
# Out:
# '/home/francesco/workspace/git/TISProject/NB_Presentazione/treetagger/Linux/'

# %% [markdown]
# ## Load dataset:

# %%
train = pd.read_csv("../Dataset/cleaned_data.csv", delimiter="\t")

# %%
print(train.shape)
train.head()
# Out:
# (9283, 2)
#               Unnamed: 0                                               body
# 0  FM20160429032ACC9MUHD  acea essere pronto giocare partita banda ultra...
# 1  FM20160501023ACLAzwID  unico certezza momento essere prossimo tappa s...
# 2  FM20160503035ACaNSzJD  potere aspettare mese luglio formalizzazione p...
# 3  FM20160503035ACDx00JD  fondo chiuso aiutare piccolo medio impresa ita...
# 4  FM20160428033ACi2kvGD  volto provocazione sortire effetto sperare ext...

# %%
train["body"] = train["body"].apply(lambda x:x.split(' '))

# %%
corp = list(train["body"])

# %% [markdown]
# ## Word2Vec model:

# %%
# Import the built-in logging module and configure it so that Word2Vec 
# creates nice output messages
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s',\
    level=logging.INFO)
# Initialize and train the model (this will take some time)
from gensim.models import word2vec

# %%
# Set values for various parameters
num_features = 300    # Word vector dimensionality                      
min_word_count = 20   # Minimum word count                        
num_workers = 4       # Number of threads to run in parallel
context = 20          # Context window size                                                                                    
downsampling = 1e-3   # Downsample setting for frequent words

# %%
print("Training model...")
model = word2vec.Word2Vec(sentences=corp, workers=num_workers, \
            size=num_features, min_count = min_word_count, \
            window = context, sample = downsampling, sorted_vocab=1)

# If you don't plan to train the model any further, calling 
# init_sims will make the model much more memory-efficient.
#model.init_sims(replace=True)


# It can be helpful to create a meaningful model name and 
# save the model for later use. You can load it later using Word2Vec.load()
model_name = "300features_40minwords_10context"
model.save(model_name)
# Out:
# 2017-05-22 19:24:24,492 : INFO : collecting all words and their counts
# 2017-05-22 19:24:24,493 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# Training model...
# 2017-05-22 19:24:25,098 : INFO : collected 34833 word types from a corpus of 1274549 raw words and 9283 sentences
# 2017-05-22 19:24:25,099 : INFO : Loading a fresh vocabulary
# 2017-05-22 19:24:25,155 : INFO : min_count=20 retains 5608 unique words (16% of original 34833, drops 29225)
# 2017-05-22 19:24:25,156 : INFO : min_count=20 leaves 1173726 word corpus (92% of original 1274549, drops 100823)
# 2017-05-22 19:24:25,186 : INFO : deleting the raw counts dictionary of 34833 items
# 2017-05-22 19:24:25,189 : INFO : sample=0.001 downsamples 32 most-common words
# 2017-05-22 19:24:25,190 : INFO : downsampling leaves estimated 1089728 word corpus (92.8% of prior 1173726)
# 2017-05-22 19:24:25,191 : INFO : estimated required memory for 5608 words and 300 dimensions: 16263200 bytes
# 2017-05-22 19:24:25,219 : INFO : resetting layer weights
# 2017-05-22 19:24:25,399 : INFO : training model with 4 workers on 5608 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=20
# 2017-05-22 19:24:25,400 : INFO : expecting 9283 sentences, matching count from corpus used for vocabulary survey
# 2017-05-22 19:24:26,944 : INFO : PROGRESS: at 0.38% examples, 27578 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:28,256 : INFO : PROGRESS: at 0.69% examples, 26700 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:29,333 : INFO : PROGRESS: at 0.96% examples, 25804 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 19:24:30,413 : INFO : PROGRESS: at 1.11% examples, 23637 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:31,425 : INFO : PROGRESS: at 1.53% examples, 26715 words/s, in_qsize 8, out_qsize 1
# 2017-05-22 19:24:32,669 : INFO : PROGRESS: at 2.25% examples, 32404 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:33,765 : INFO : PROGRESS: at 2.92% examples, 36060 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:35,034 : INFO : PROGRESS: at 3.66% examples, 39120 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:36,183 : INFO : PROGRESS: at 4.30% examples, 41166 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 19:24:37,242 : INFO : PROGRESS: at 4.81% examples, 42498 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:38,297 : INFO : PROGRESS: at 5.36% examples, 43528 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:39,450 : INFO : PROGRESS: at 5.89% examples, 42951 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:40,757 : INFO : PROGRESS: at 6.66% examples, 40981 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:42,229 : INFO : PROGRESS: at 7.71% examples, 39449 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:43,431 : INFO : PROGRESS: at 8.69% examples, 38696 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:44,551 : INFO : PROGRESS: at 10.59% examples, 39987 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 19:24:45,737 : INFO : PROGRESS: at 12.28% examples, 40564 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:47,109 : INFO : PROGRESS: at 13.94% examples, 40764 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:48,189 : INFO : PROGRESS: at 15.69% examples, 41435 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:49,261 : INFO : PROGRESS: at 16.90% examples, 41348 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:50,619 : INFO : PROGRESS: at 18.15% examples, 40818 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:52,530 : INFO : PROGRESS: at 19.19% examples, 39203 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:54,389 : INFO : PROGRESS: at 20.06% examples, 37860 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:55,533 : INFO : PROGRESS: at 20.44% examples, 37808 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 19:24:56,600 : INFO : PROGRESS: at 20.93% examples, 38131 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 19:24:57,779 : INFO : PROGRESS: at 21.35% examples, 38052 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:58,783 : INFO : PROGRESS: at 21.76% examples, 38153 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:24:59,970 : INFO : PROGRESS: at 22.23% examples, 38279 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:00,979 : INFO : PROGRESS: at 22.71% examples, 38613 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:02,265 : INFO : PROGRESS: at 23.14% examples, 38372 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:03,295 : INFO : PROGRESS: at 23.58% examples, 38441 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 19:25:04,554 : INFO : PROGRESS: at 23.80% examples, 37861 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:05,814 : INFO : PROGRESS: at 24.13% examples, 37509 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 19:25:07,122 : INFO : PROGRESS: at 24.44% examples, 37133 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:08,170 : INFO : PROGRESS: at 24.80% examples, 37212 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 19:25:09,213 : INFO : PROGRESS: at 25.27% examples, 37454 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:10,254 : INFO : PROGRESS: at 25.70% examples, 37505 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:11,729 : INFO : PROGRESS: at 26.88% examples, 37250 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:12,856 : INFO : PROGRESS: at 28.43% examples, 37450 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:14,304 : INFO : PROGRESS: at 29.82% examples, 37377 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 19:25:15,407 : INFO : PROGRESS: at 30.78% examples, 37233 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:16,496 : INFO : PROGRESS: at 31.51% examples, 36933 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:17,553 : INFO : PROGRESS: at 32.00% examples, 36507 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:18,573 : INFO : PROGRESS: at 32.71% examples, 36295 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 19:25:19,633 : INFO : PROGRESS: at 34.11% examples, 36527 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:20,790 : INFO : PROGRESS: at 36.31% examples, 37141 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:21,911 : INFO : PROGRESS: at 38.89% examples, 37918 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:23,103 : INFO : PROGRESS: at 40.28% examples, 38317 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:24,113 : INFO : PROGRESS: at 40.98% examples, 38941 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:25,227 : INFO : PROGRESS: at 41.74% examples, 39477 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:26,456 : INFO : PROGRESS: at 42.46% examples, 39920 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:27,532 : INFO : PROGRESS: at 42.97% examples, 40026 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:28,802 : INFO : PROGRESS: at 43.38% examples, 39884 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:30,141 : INFO : PROGRESS: at 43.80% examples, 39706 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:31,143 : INFO : PROGRESS: at 44.19% examples, 39739 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:32,166 : INFO : PROGRESS: at 44.85% examples, 40264 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 19:25:33,263 : INFO : PROGRESS: at 45.60% examples, 40726 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 19:25:34,386 : INFO : PROGRESS: at 47.70% examples, 41187 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 19:25:35,550 : INFO : PROGRESS: at 50.29% examples, 41830 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:36,581 : INFO : PROGRESS: at 52.47% examples, 42301 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:37,645 : INFO : PROGRESS: at 54.66% examples, 42741 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:38,788 : INFO : PROGRESS: at 56.78% examples, 43114 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:39,839 : INFO : PROGRESS: at 58.38% examples, 43200 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:40,944 : INFO : PROGRESS: at 59.64% examples, 43134 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 19:25:41,982 : INFO : PROGRESS: at 60.36% examples, 43207 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:43,104 : INFO : PROGRESS: at 60.74% examples, 43125 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:44,170 : INFO : PROGRESS: at 61.58% examples, 43610 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:45,294 : INFO : PROGRESS: at 62.62% examples, 44356 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:46,513 : INFO : PROGRESS: at 63.55% examples, 44814 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:47,709 : INFO : PROGRESS: at 64.43% examples, 45284 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:48,916 : INFO : PROGRESS: at 65.02% examples, 45438 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:50,005 : INFO : PROGRESS: at 65.70% examples, 45645 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:51,339 : INFO : PROGRESS: at 67.15% examples, 45543 words/s, in_qsize 8, out_qsize 1
# 2017-05-22 19:25:52,393 : INFO : PROGRESS: at 68.21% examples, 45388 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:53,522 : INFO : PROGRESS: at 69.12% examples, 45190 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 19:25:54,729 : INFO : PROGRESS: at 70.29% examples, 45051 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:55,787 : INFO : PROGRESS: at 72.47% examples, 45371 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:56,844 : INFO : PROGRESS: at 74.37% examples, 45594 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:25:57,990 : INFO : PROGRESS: at 77.09% examples, 46036 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 19:25:59,044 : INFO : PROGRESS: at 79.17% examples, 46249 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:26:00,153 : INFO : PROGRESS: at 80.50% examples, 46601 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:26:01,263 : INFO : PROGRESS: at 81.33% examples, 46943 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:26:02,268 : INFO : PROGRESS: at 82.06% examples, 47233 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:26:03,288 : INFO : PROGRESS: at 82.62% examples, 47334 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:26:04,405 : INFO : PROGRESS: at 83.13% examples, 47310 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:26:05,726 : INFO : PROGRESS: at 83.63% examples, 47181 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:26:06,822 : INFO : PROGRESS: at 84.12% examples, 47170 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:26:07,851 : INFO : PROGRESS: at 84.70% examples, 47355 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:26:08,852 : INFO : PROGRESS: at 85.35% examples, 47545 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:26:09,906 : INFO : PROGRESS: at 87.10% examples, 47884 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:26:10,966 : INFO : PROGRESS: at 89.59% examples, 48212 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:26:12,010 : INFO : PROGRESS: at 92.00% examples, 48532 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:26:13,103 : INFO : PROGRESS: at 94.37% examples, 48833 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 19:26:14,232 : INFO : PROGRESS: at 96.60% examples, 49029 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 19:26:15,243 : INFO : PROGRESS: at 98.89% examples, 49277 words/s, in_qsize 5, out_qsize 0
# 2017-05-22 19:26:15,592 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-05-22 19:26:15,753 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-05-22 19:26:15,808 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-05-22 19:26:15,842 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-05-22 19:26:15,843 : INFO : training on 6372745 raw words (5449458 effective words) took 110.4s, 49351 effective words/s
# 2017-05-22 19:26:15,847 : INFO : saving Word2Vec object under 300features_40minwords_10context, separately None
# 2017-05-22 19:26:15,849 : INFO : not storing attribute syn0norm
# 2017-05-22 19:26:15,851 : INFO : not storing attribute cum_table
# 2017-05-22 19:26:16,579 : INFO : saved 300features_40minwords_10context

# %%
model.most_similar("quotazione")
# Out:
# 2017-05-22 19:26:16,590 : INFO : precomputing L2-norms of word weight vectors
# [('borsa', 0.9192878603935242),
#  ('mta', 0.8376414775848389),
#  ('ipo', 0.8232322931289673),
#  ('essere_quotare', 0.7730789184570312),
#  ('listino', 0.7660068869590759),
#  ('quotare', 0.7635006308555603),
#  ('star', 0.749306321144104),
#  ('aim', 0.7476506233215332),
#  ('sbarco', 0.7222742438316345),
#  ('matricola', 0.7111003398895264)]

# %%
model.most_similar("3")
# Out:
# [('4', 0.9296406507492065),
#  ('2', 0.9208474159240723),
#  ('5', 0.8889598250389099),
#  ('1', 0.8606124520301819),
#  ('7', 0.8413089513778687),
#  ('6', 0.7879739999771118),
#  ('8', 0.778730034828186),
#  ('10', 0.7547396421432495),
#  ('9', 0.6955190896987915),
#  ('15', 0.665380597114563)]

# %%
model.most_similar("potere")
# Out:
# [('dovere', 0.8181290626525879),
#  ('possibilità', 0.7790635228157043),
#  ('escludere', 0.7641160488128662),
#  ('magari', 0.7627406716346741),
#  ('quindi', 0.7558209896087646),
#  ('sufficiente', 0.7555112838745117),
#  ('senza', 0.7545698881149292),
#  ('perchè', 0.7536015510559082),
#  ('dipendere', 0.7508028745651245),
#  ('dunque', 0.7500941753387451)]

# %%
model.most_similar("radiocor")
# Out:
# [('plus', 0.9474889636039734),
#  ('sole24ore', 0.8701058030128479),
#  ('dalsole24ore', 0.8234608173370361),
#  ('indiscrezione', 0.7850154638290405),
#  ('intervista', 0.7701559066772461),
#  ('stampa', 0.7632895112037659),
#  ('ufficialmente', 0.7394756078720093),
#  ('riunire', 0.7148219347000122),
#  ('domani', 0.7114574313163757),
#  ('agenda', 0.7104169130325317)]

# %%
model.wv.syn0.shape
# Out:
# (5608, 300)

# %%
x = {}
for word, vocab_obj in model.wv.vocab.items():
    #print('--------------------------')
    #print(word)
    #print(vocab_obj.count)
    x[word] = vocab_obj.count

# %%
import operator
sorted_x = sorted(x.items(), key=operator.itemgetter(1), reverse= True)
print(sorted_x)
# Out:
# [('avere', 30935), ('milione', 19728), ('essere', 19288), ('euro', 9220), ('gruppo', 9210), ('anno', 7715), ('primo', 6242), ('nuovo', 5737), ('mercato', 5561), ('miliardo', 5179), ('fare', 4845), ('essere_stare', 4515), ('potere', 4439), ('azione', 4422), ('stare', 4313), ('2015', 4255), ('netto', 4184), ('crescita', 4181), ('operazione', 4008), ('società', 3953), ('altro', 3930), ('circa', 3855), ('capitale', 3833), ('pari', 3574), ('parte', 3557), ('mese', 3498), ('italia', 3423), ('fine', 3323), ('2014', 3280), ('1', 3272), ('finanziario', 3208), ('due', 3139), ('ricavo', 3062), ('risultato', 2989), ('prevedere', 2913), ('piano', 2884), ('secondo', 2806), ('dovere', 2805), ('italiano', 2789), ('rispetto', 2777), ('scorso', 2771), ('settore', 2760), ('proprio', 2697), ('grande', 2621), ('investimento', 2618), ('quota', 2591), ('oltre', 2577), ('azienda', 2566), ('ieri', 2564), ('vendita', 2507), ('prezzo', 2496), ('presidente', 2471), ('utile', 2463), ('stesso', 2460), ('aumento', 2420), ('nota', 2406), ('offerta', 2370), ('azionista', 2347), ('oggi', 2315), ('dopo', 2306), ('ultimo', 2277), ('2', 2246), ('accordo', 2203), ('dire', 2162), ('cda', 2139), ('valore', 2127), ('banca', 2101), ('fondo', 2096), ('titolo', 2095), ('assemblea', 2091), ('periodo', 2075), ('trimestre', 2053), ('industriale', 2037), ('2016', 2026), ('molto', 2012), ('già', 2002), ('progetto', 2000), ('business', 1990), ('operativo', 1975), ('poi', 1948), ('positivo', 1922), ('spiegare', 1914), ('socio', 1899), ('prossimo', 1887), ('ebitda', 1878), ('solo', 1864), ('mentre', 1862), ('ancora', 1844), ('chiudere', 1817), ('acquisizione', 1800), ('3', 1791), ('linea', 1787), ('esercizio', 1771), ('sviluppo', 1762), ('borsa', 1679), ('amministratore', 1679), ('rispettare', 1672), ('vedere', 1660), ('obiettivo', 1641), ('confermare', 1633), ('5', 1617), ('contratto', 1563), ('importante', 1554), ('corso', 1543), ('4', 1540), ('registrare', 1534), ('termine', 1523), ('0', 1484), ('giorno', 1482), ('venire', 1474), ('fatturato', 1474), ('margine', 1452), ('quindi', 1441), ('entro', 1437), ('debito', 1431), ('servizio', 1429), ('fino', 1426), ('partecipazione', 1414), ('andare', 1412), ('dicembre', 1409), ('tre', 1400), ('infatti', 1399), ('ora', 1397), ('gestione', 1390), ('punto', 1387), ('dare', 1380), ('paese', 1378), ('invece', 1366), ('energia', 1366), ('area', 1364), ('tempo', 1355), ('sottolineare', 1351), ('complessivo', 1346), ('fronte', 1345), ('portare', 1339), ('sempre', 1331), ('conto', 1323), ('livello', 1314), ('inoltre', 1307), ('annunciare', 1294), ('acquisto', 1262), ('attraverso', 1251), ('cambio', 1243), ('mondo', 1242), ('portafoglio', 1230), ('posizione', 1225), ('bilancio', 1224), ('approvare', 1211), ('particolare', 1211), ('saipem', 1207), ('31', 1202), ('controllare', 1193), ('ulteriore', 1190), ('cessione', 1188), ('presentare', 1187), ('semestre', 1183), ('milano', 1179), ('delegare', 1174), ('mettere', 1172), ('enel', 1170), ('realizzare', 1163), ('30', 1163), ('volta', 1158), ('base', 1155), ('effetto', 1154), ('caso', 1151), ('però', 1149), ('investitore', 1148), ('numero', 1146), ('9', 1146), ('consiglio', 1140), ('opa', 1140), ('generale', 1138), ('calo', 1136), ('dato', 1130), ('giugno', 1129), ('arrivare', 1123), ('dollaro', 1122), ('forte', 1119), ('impianto', 1119), ('dividendo', 1116), ('possibile', 1111), ('attività', 1091), ('strategico', 1089), ('raggiungere', 1088), ('6', 1086), ('continuare', 1070), ('costo', 1068), ('totale', 1061), ('prodotto', 1058), ('holding', 1056), ('sts', 1055), ('medio', 1054), ('lavoro', 1049), ('gas', 1047), ('hitachi', 1041), ('aggiungere', 1039), ('cairo', 1038), ('affare', 1037), ('2014.', 1031), ('volere', 1029), ('consob', 1029), ('comunicare', 1028), ('rete', 1025), ('asset', 1022), ('controllo', 1019), ('marzo', 1010), ('futuro', 1007), ('attuale', 1006), ('massimo', 1006), ('telecom', 995), ('momento', 993), ('europa', 991), ('rcs', 988), ('7', 984), ('miglioramento', 983), ('produz ...

# %%
reverse_dictionary = {}
for idx,h in enumerate(sorted_x):
    reverse_dictionary[idx] = h[0]
    
reverse_dictionary
# Out:
# {0: 'avere',
#  1: 'milione',
#  2: 'essere',
#  3: 'euro',
#  4: 'gruppo',
#  5: 'anno',
#  6: 'primo',
#  7: 'nuovo',
#  8: 'mercato',
#  9: 'miliardo',
#  10: 'fare',
#  11: 'essere_stare',
#  12: 'potere',
#  13: 'azione',
#  14: 'stare',
#  15: '2015',
#  16: 'netto',
#  17: 'crescita',
#  18: 'operazione',
#  19: 'società',
#  20: 'altro',
#  21: 'circa',
#  22: 'capitale',
#  23: 'pari',
#  24: 'parte',
#  25: 'mese',
#  26: 'italia',
#  27: 'fine',
#  28: '2014',
#  29: '1',
#  30: 'finanziario',
#  31: 'due',
#  32: 'ricavo',
#  33: 'risultato',
#  34: 'prevedere',
#  35: 'piano',
#  36: 'secondo',
#  37: 'dovere',
#  38: 'italiano',
#  39: 'rispetto',
#  40: 'scorso',
#  41: 'settore',
#  42: 'proprio',
#  43: 'grande',
#  44: 'investimento',
#  45: 'quota',
#  46: 'oltre',
#  47: 'azienda',
#  48: 'ieri',
#  49: 'vendita',
#  50: 'prezzo',
#  51: 'presidente',
#  52: 'utile',
#  53: 'stesso',
#  54: 'aumento',
#  55: 'nota',
#  56: 'offerta',
#  57: 'azionista',
#  58: 'oggi',
#  59: 'dopo',
#  60: 'ultimo',
#  61: '2',
#  62: 'accordo',
#  63: 'dire',
#  64: 'cda',
#  65: 'valore',
#  66: 'banca',
#  67: 'fondo',
#  68: 'titolo',
#  69: 'assemblea',
#  70: 'periodo',
#  71: 'trimestre',
#  72: 'industriale',
#  73: '2016',
#  74: 'molto',
#  75: 'già',
#  76: 'progetto',
#  77: 'business',
#  78: 'operativo',
#  79: 'poi',
#  80: 'positivo',
#  81: 'spiegare',
#  82: 'socio',
#  83: 'prossimo',
#  84: 'ebitda',
#  85: 'solo',
#  86: 'mentre',
#  87: 'ancora',
#  88: 'chiudere',
#  89: 'acquisizione',
#  90: '3',
#  91: 'linea',
#  92: 'esercizio',
#  93: 'sviluppo',
#  94: 'borsa',
#  95: 'amministratore',
#  96: 'rispettare',
#  97: 'vedere',
#  98: 'obiettivo',
#  99: 'confermare',
#  100: '5',
#  101: 'contratto',
#  102: 'importante',
#  103: 'corso',
#  104: '4',
#  105: 'registrare',
#  106: 'termine',
#  107: '0',
#  108: 'giorno',
#  109: 'venire',
#  110: 'fatturato',
#  111: 'margine',
#  112: 'quindi',
#  113: 'entro',
#  114: 'debito',
#  115: 'servizio',
#  116: 'fino',
#  117: 'partecipazione',
#  118: 'andare',
#  119: 'dicembre',
#  120: 'tre',
#  121: 'infatti',
#  122: 'ora',
#  123: 'gestione',
#  124: 'punto',
#  125: 'dare',
#  126: 'paese',
#  127: 'invece',
#  128: 'energia',
#  129: 'area',
#  130: 'tempo',
#  131: 'sottolineare',
#  132: 'complessivo',
#  133: 'fronte',
#  134: 'portare',
#  135: 'sempre',
#  136: 'conto',
#  137: 'livello',
#  138: 'inoltre',
#  139: 'annunciare',
#  140: 'acquisto',
#  141: 'attraverso',
#  142: 'cambio',
#  143: 'mondo',
#  144: 'portafoglio',
#  145: 'posizione',
#  146: 'bilancio',
#  147: 'approvare',
#  148: 'particolare',
#  149: 'saipem',
#  150: '31',
#  151: 'controllare',
#  152: 'ulteriore',
#  153: 'cessione',
#  154: 'presentare',
#  155: 'semestre',
#  156: 'milano',
#  157: 'delegare',
#  158: 'mettere',
#  159: 'enel',
#  160: 'realizzare',
#  161: '30',
#  162: 'volta',
#  163: 'base',
#  164: 'effetto',
#  165: 'caso',
#  166: 'però',
#  167: 'investitore',
#  168: 'numero',
#  169: '9',
#  170: 'consiglio',
#  171: 'opa',
#  172: 'generale',
#  173: 'calo',
#  174: 'dato',
#  175: 'giugno',
#  176: 'arrivare',
#  177: 'dollaro',
#  178: 'forte',
#  179: 'impianto',
#  180: 'dividendo',
#  181: 'possibile',
#  182: 'attività',
#  183: 'strategico',
#  184: 'raggiungere',
#  185: '6',
#  186: 'continuare',
#  187: 'costo',
#  188: 'totale',
#  189: 'prodotto',
#  190: 'holding',
#  191: 'sts',
#  192: 'medio',
#  193: 'lavoro',
#  194: 'gas',
#  195: 'hitachi',
#  196: 'aggiungere',
#  197: 'cairo',
#  198: 'affare',
#  199: '2014.',
#  200: 'volere',
#  201: 'consob',
#  202: 'comunicare',
#  203: 'rete',
#  204: 'asset',
#  205: 'controllo',
#  206: 'marzo',
#  207: 'futuro',
#  208: 'attuale',
#  209: 'massimo',
#  210: 'telecom',
#  211: 'momento',
#  212: 'europa',
#  213: 'rcs',
#  214: '7',
#  215: 'miglioramento',
#  216: 'produzione',
#  217: 'relativo',
#  218: 'cassa',
#  219: 'detenere',
#  220: 'negativo',
#  221: 'soprattutto',
#  222: 'strategia',
#  223: 'indebitamento',
#  224: 'stato',
#  225: 'principale',
#  226: '2015.',
#  227: 'pubblico',
#  228: 'diritto',
#  229: 'internazionale',
#  230: 'interesse',
#  231: 'comunque',
#  232: 'via',
#  233: 'terzo',
#  234: 'poco',
#  235: 'così',
#  236: 'amministrazione',
#  237: 'diverso',
#  238: 'incremento',
#  239: '8',
#  240: 'ansaldo',
#  241: '10',
#  242: 'ordine',
#  243: 'restare',
#  244: 'manager',
#  245: 'condizione',
#  246: 'settembre',
#  247: 'precedente',
#  248: 'lungo',
#  249: 'concludere',
#  250: 'gestire',
#  251: 'ex',
#  252: 'crescere',
#  253: 'distribuzione',
#  254: 'sistema',
#  255: 'processo',
#  256: 'eni',
#  257: 'quando',
#  258: 'rappresentare',
#  259: 'consentire',
#  260: '–',
#  261: 'andamento',
#  262: '2_percento',
#  263: 'guidare',
#  264: 'a2a',
#  265: 'ogni',
#  266: 'commentare',
#  267: 'rendere',
#  268: 'attivo',
#  269: 'tale',
#  270: 'riguardare',
#  271: '2013',
#  272: 'management',
#  273: 'senza',
#  274: 'ricordare',
#  275: 'controllato',
#  276: 'famiglia',
#  277: 'operatore',
#  278: 'd',
#  279: 'salire',
#  280: 'sotto',
#  281: 'modo',
#  282: 'cliente',
#  283: 'estero',
#  284: 'noto',
#  285: 'economico',
#  286: 'alcuni',
#  287: 'risultare',
#  288: 'puntare',
#  289: 'fatto',
#  290: 'alto',
#  291: 'straordinario',
#  292: '1_percento',
#  293: 'trattare',
#  294: 'fusione',
#  295: 'rai',
#  296: 'quasi',
#  297: 'torre',
#  298: 'grazie',
#  299: 'decidere',
#  300: 'perdita',
#  301: 'ordinario',
#  302: 'luglio',
#  303: 'settimana',
#  304: 'lordo',
#  305: 'offrire',
#  306: 'aprile',
#  307: 'europeo',
#  308: 'marco',
#  309: 'nove',
#  310: 'sottoscrivere',
#  311: 'proseguire',
#  312: 'maggio',
#  313: 'piazza',
#  314: 'sociale',
#  315: 'fase',
#  316: 'aumentare',
#  317: 'riferimento',
#  318: 'costruzione',
#  319: 'data',
#  320: 'finmeccanica',
#  321: 'dichiarare',
#  322: 'gennaio',
#  323: 'meno',
#  324: 'credito',
#  325: 'avviare',
#  326: 'partire',
#  327: 'precisare',
#  328: 'programma',
#  329: 'chiedere',
#  330: 'investire',
#  331: '15',
#  332: 'group',
#  333: 'dunque',
#  334: 'comunicato',
#  335: 'partner',
#  336: '5_percento',
#  337: 'inizio',
#  338: 'pario',
#  339: 'rilevare',
#  340: 'consolidare',
#  341: 'immobiliare',
#  342: 'vendere',
#  343: '12',
#  344: 'america',
#  345: 'emissione',
#  346: 'ridurre',
#  347: 'domanda',
#  348: 'leggere',
#  349: 'permettere',
#  350: 'intero',
#  351: 'decisione',
#  352: 'guardare',
#  353: 'presenza',
#  354: 'considerare',
#  355: '3_percento',
#  356: 'bene',
#  357: 'quotazione',
#  358: 'tasso',
#  359: 'riduzione',
#  360: 'tuttavia',
#  361: 'nord',
#  362: 'commerciale',
#  363: 'febbraio',
#  364: 'consigliere',
#  365: 'capital',
#  366: 'prendere',
#  367: 'power',
#  368: 'indicare',
#  369: 'integrazione',
#  370: 'eventuale',
#  371: 'superiore',
#  372: 'prima',
#  373: 'infine',
#  374: '20',
#  375: 'unico',
#  376: 'verso',
#  377: 'rapporto',
#  378: 'tenere',
#  379: '4_percento',
#  380: 'rialzo',
#  381: 'costante',
#  382: 'risparmio',
#  383: '10_percento',
#  384: 'de',
#  385: 'ottenere',
#  386: 'rafforzare',
#  387: 'proposta',
#  388: 'realizzazione',
#  389: 'opzione',
#  390: 'significativo',
#  391: 'performance',
#  392: 'seguito',
#  393: 'entrare',
#  394: 'comprendere',
#  395: 'grazia',
#  396: 'alcune',
#  397: 'fra',
#  398: 's',
#  399: 'ammontare',
#  400: 'target',
#  401: 'impresa',
#  402: 'elettrico',
#  403: 'struttura',
#  404: 'tv',
#  405: 'comune',
#  406: 'sede',
#  407: 'capo',
#  408: 'segmento',
#  409: 'ritenere',
#  410: 'attendere',
#  411: 'interno',
#  412: 'analista',
#  413: 'esempio',
#  414: 'impegno',
#  415: 'aprire',
#  416: 'governo',
#  417: 'pagamento',
#  418: 'scadenza',
#  419: 'lanciare',
#  420: 'nominare',
#  421: '6_percento',
#  422: 'fincantieri',
#  423: 'situazione',
#  424: 'ottobre',
#  425: 'novembre',
#  426: 'maggioranza',
#  427: 'francese',
#  428: 'necessario',
#  429: 'quotare',
#  430: 'green',
#  431: 'ruolo',
#  432: 'snam',
#  433: 'ebit',
#  434: 'stabile',
#  435: 'proporre',
#  436: 'buono',
#  437: 'scendere',
#  438: 'consolidato',
#  439: 'garantire',
#  440: 'diventare',
#  441: 'impatto',
#  442: 'trovare',
#  443: 'generare',
#  444: 'cedere',
#  445: 'lavorare',
#  446: 'cosa',
#  447: 'attestare',
#  448: 'recente',
#  449: 'rimanere',
#  450: 'inwit',
#  451: 'cioè',
#  452: 'qui',
#  453: 'ei',
#  454: 'ceo',
#  455: 'tanto',
#  456: 'valutare',
#  457: 'ben',
#  458: 'passare',
#  459: 'avvenire',
#  460: 'risorsa',
#  461: 'towers',
#  462: 'pagare',
#  463: 'presente',
#  464: 'parlare',
#  465: 'partecipare',
#  466: '11',
#  467: 'acquistare',
#  468: 'mantenere',
#  469: 'aeroporto',
#  470: '0_percento',
#  471: 'energetico',
#  472: 'tecnologia',
#  473: 'qualche',
#  474: 'privato',
#  475: '14',
#  476: 'acquisire',
#  477: 'ambito',
#  478: 'bond',
#  479: 'certo',
#  480: '50_percento',
#  481: 'vista',
#  482: 'opera',
#  483: 'mol',
#  484: 'americano',
#  485: 'way',
#  486: 'valere',
#  487: 'sgr',
#  488: '18',
#  489: 'produrre',
#  490: 'rischio',
#  491: 'nonostante',
#  492: 'veicolo',
#  493: 'sostenere',
#  494: 'francesco',
#  495: 'consolidamento',
#  496: 'soggetto',
#  497: 'rispondere',
#  498: 'finanziamento',
#  499: 'passo',
#  500: 'creare',
#  501: 'prospettiva',
#  502: 'nazionale',
#  503: 'intendere',
#  504: 'unicredit',
#  505: 'roma',
#  506: 'efficienza',
#  507: 'valutazione',
#  508: 'grado',
#  509: 'richiesta',
#  510: 'soluzione',
#  511: 'confronto',
#  512: 'infrastruttura',
#  513: 'minoranza',
#  514: 'board',
#  515: '25',
#  516: 'aggiunto',
#  517: 'affermare',
#  518: 'raccolta',
#  519: 'leader',
#  520: '16',
#  521: 'retail',
#  522: '2016.',
#  523: 'oggetto',
#  524: '100_percento',
#  525: 'esprimere',
#  526: 'valle',
#  527: 'successo',
#  528: 'insieme',
#  529: 'direttore',
#  530: 'commissione',
#  531: 'essere_salire',
#  532: 'deliberare',
#  533: 'occasione',
#  534: 'sviluppare',
#  535: 'caltagirone',
#  536: '40_percento',
#  537: 'ingresso',
#  538: 'piccolo',
#  539: 'completare',
#  540: 'migliore',
#  541: 'cina',
#  542: 'segnare',
#  543: 'tornare',
#  544: 'advisor',
#  545: 'rinnovabile',
#  546: '8_percento',
#  547: 'canale',
#  548: 'patrimonio',
#  549: 'luxottica',
#  550: 'attualmente',
#  551: 'avanti',
#  552: 'uso',
#  553: '2017',
#  554: 'migliorare',
#  555: 'superare',
#  556: 'equity',
#  557: 'costituire',
#  558: 'istituzionale',
#  559: 'marchio',
#  560: 'libero',
#  561: 'gara',
#  562: 'generazione',
#  563: 'contesto',
#  564: 'destinare',
#  565: '13',
#  566: 'sembrare',
#  567: 'industria',
#  568: 'territorio',
#  569: 'atlantia',
#  570: '20_percento',
#  571: 'pensare',
#  572: 'tramite',
#  573: 'paolo',
#  574: 'ciò',
#  575: 'almeno',
#  576: 'partnership',
#  577: 'mila',
#  578: 'seguire',
#  579: 'nave',
#  580: 'pronto',
#  581: 'definire',
#  582: 'spa',
#  583: 'anima',
#  584: 'globale',
#  585: 'mondiale',
#  586: 'giro',
#  587: 'effettuare',
#  588: 'tema',
#  589: 'mediobanca',
#  590: 'sapere',
#  591: '7_percento',
#  592: 'indipendente',
#  593: 'approvazione',
#  594: 'casa',
#  595: 'complesso',
#  596: 'cinque',
#  597: 'divisione',
#  598: '500',
#  599: 'comunicazione',
#  600: 'vecchio',
#  601: '24',
#  602: 'quattro',
#  603: 'legare',
#  604: 'voto',
#  605: 'imo',
#  606: 'capacità',
#  607: 'rilevante',
#  608: 'eolico',
#  609: 'ricavare',
#  610: 'stima',
#  611: 'italcementi',
#  612: 'firmare',
#  613: '50',
#  614: 'escludere',
#  615: 'brand',
#  616: 'legale',
#  617: 'componente',
#  618: 'atto',
#  619: 'riferire',
#  620: 'redditività',
#  621: 'porre',
#  622: 'percorso',
#  623: 'giovanni',
#  624: 'iniziare',
#  625: 'resto',
#  626: 'vertice',
#  627: 'principalmente',
#  628: 'potenziale',
#  629: 'iniziativa',
#  630: 'scelta',
#  631: 'nettare',
#  632: 'fonte',
#  633: 'mano',
#  634: 'contare',
#  635: 'ricevere',
#  636: 'peraltro',
#  637: 'ristrutturazione',
#  638: 'alcun',
#  639: '000',
#  640: 'acea',
#  641: 'stimare',
#  642: 'produttivo',
#  643: 'sito',
#  644: 'prelios',
#  645: '30_percento',
#  646: 'cinese',
#  647: 'tedesco',
#  648: 'locale',
#  649: 'basso',
#  650: 'unito',
#  651: 'trattativa',
#  652: '100',
#  653: 'includere',
#  654: 'stefano',
#  655: 'relazione',
#  656: 'previsione',
#  657: 'storico',
#  658: 'passaggio',
#  659: '1.',
#  660: 'breve',
#  661: 'modello',
#  662: 'cdp',
#  663: 'indicazione',
#  664: 'attesa',
#  665: 'senso',
#  666: 'vincolante',
#  667: 'imprenditore',
#  668: 'piaggiare',
#  669: 'ormai',
#  670: 'difficile',
#  671: 'patto',
#  672: 'aspettare',
#  673: 'lista',
#  674: 'sinergia',
#  675: 'chiusura',
#  676: 'mw',
#  677: 'richiedere',
#  678: 'importo',
#  679: 'carlo',
#  680: 'azionario',
#  681: 'fissare',
#  682: 'bank',
#  683: 'edison',
#  684: 'campo',
#  685: 'giuseppe',
#  686: 'evidenziare',
#  687: 'centro',
#  688: 'centrale',
#  689: 'intesa',
#  690: 'piattaforma',
#  691: 'procedura',
#  692: 'compagnia',
#  693: 'cedola',
#  694: 'uscire',
#  695: 'prestito',
#  696: 'volume',
#  697: 'studio',
#  698: 'iren',
#  699: 'finalizzare',
#  700: 'tribunale',
#  701: 'negozio',
#  702: 'istituto',
#  703: 'onere',
#  704: 'autostrada',
#  705: 'colosso',
#  706: 'communication',
#  707: 'attenzione',
#  708: 'fornire',
#  709: 'ulteriormente',
#  710: 'presso',
#  711: 'commessa',
#  712: 'competenza',
#  713: '15_percento',
#  714: 'ricerca',
#  715: 'appena',
#  716: '17',
#  717: 'strada',
#  718: 'procedere',
#  719: 'annuo',
#  720: 'impregilo',
#  721: 'contributo',
#  722: 'chiaro',
#  723: 'incontro',
#  724: '40',
#  725: 'agosto',
#  726: 'nomina',
#  727: 'trend',
#  728: 'serie',
#  729: 'media',
#  730: 'ribadire',
#  731: 'legge',
#  732: 'pacchetto',
#  733: 'emergere',
#  734: 'opportunità',
#  735: 'derivare',
#  736: 'causa',
#  737: 'entrambi',
#  738: 'passato',
#  739: 'essere_prevedere',
#  740: 'bancario',
#  741: 'quotato',
#  742: 'rating',
#  743: 'progresso',
#  744: 'scenario',
#  745: '200',
#  746: 'distribuire',
#  747: 'indiscrezione',
#  748: 'lasciare',
#  749: 'merito',
#  750: 'metà',
#  751: '21',
#  752: 'durante',
#  753: 'popolare',
#  754: 'joint',
#  755: 'fornitura',
#  756: 'dossier',
#  757: 'vicino',
#  758: 'espansione',
#  759: 'cifra',
#  760: 'assicurare',
#  761: 'parto',
#  762: 'contribuire',
#  763: 'visto',
#  764: 'dettaglio',
#  765: '29',
#  766: 'dipendente',
#  767: 'finale',
#  768: 'attorno',
#  769: 'rilancio',
#  770: 'parmalat',
#  771: 'avvio',
#  772: 'andrea',
#  773: '19',
#  774: 'mandare',
#  775: '12_percento',
#  776: 'idea',
#  777: 'rosso',
#  778: 'estate',
#  779: '28',
#  780: 'meglio',
#  781: 'essere_arrivare',
#  782: '9_percento',
#  783: 'possedere',
#  784: 'controvalore',
#  785: 'posto',
#  786: 'durata',
#  787: 'elevato',
#  788: 'digitale',
#  789: 'minimo',
#  790: '25_percento',
#  791: 'presentazione',
#  792: 'inferiore',
#  793: 'dinamica',
#  794: 'closing',
#  795: 'comprare',
#  796: '11_percento',
#  797: 'sopra',
#  798: 'metro',
#  799: 'flusso',
#  800: 'prysmian',
#  801: '22',
#  802: 'perimetro',
#  803: 'licenza',
#  804: 'astaldi',
#  805: 'crisi',
#  806: 'quarto',
#  807: '60_percento',
#  808: 'geografico',
#  809: 'spingere',
#  810: 'ipo',
#  811: 'successivo',
#  812: '23',
#  813: 'carica',
#  814: 'cordata',
#  815: 'corrispettivo',
#  816: 'collocamento',
#  817: '2013.',
#  818: 'concessione',
#  819: 'segnale',
#  820: 'solido',
#  821: 'buon',
#  822: 'soglia',
#  823: 'mediaset',
#  824: 'adesione',
#  825: 'antitrust',
#  826: 'aziendale',
#  827: 'industrial',
#  828: 'apertura',
#  829: 'siglare',
#  830: 'preliminare',
#  831: 'cambiare',
#  832: 'problema',
#  833: 'vero',
#  834: 'riportare',
#  835: 'servire',
#  836: 'organico',
#  837: 'nome',
#  838: 'raccogliere',
#  839: '300',
#  840: 'obbligazione',
#  841: 'persona',
#  842: 'realtà',
#  843: 'brasile',
#  844: 'corrente',
#  845: 'complessivamente',
#  846: 'trasporto',
#  847: 'international',
#  848: 'delegato',
#  849: 'favore',
#  850: 'partita',
#  851: 'insomma',
#  852: 'minore',
#  853: 'mezzo',
#  854: 'esecutivo',
#  855: 'mai',
#  856: 'operare',
#  857: 'multiutility',
#  858: 'seduta',
#  859: 'radiocor',
#  860: 'pininfarina',
#  861: 'quadro',
#  862: 'conseguire',
#  863: 'valorizzazione',
#  864: 'cavo',
#  865: 'favorevole',
#  866: 'immobile',
#  867: 'guida',
#  868: 'finanziare',
#  869: 'diffondere',
#  870: 'aim',
#  871: 'assumere',
#  872: 'tecnico',
#  873: 'innovativo',
#  874: 'collaborazione',
#  875: 'esito',
#  876: 'peso',
#  877: 'costruire',
#  878: '51_percento',
#  879: 'rispettivamente',
#  880: 'focus',
#  881: 'definitivo',
#  882: 'dimostrare',
#  883: 'stabilimento',
#  884: 'beneficiare',
#  885: 'urbano',
#  886: 'intorno',
#  887: '27',
#  888: 'egp',
#  889: 'comitato',
#  890: 'incrementare',
#  891: 'documento',
#  892: 'appunto',
#  893: 'governance',
#  894: 'utilizzare',
#  895: 'sottoscrizione',
#  896: 'call',
#  897: 'riservare',
#  898: 'intervento',
#  899: 'comparto',
#  900: 'consorzio',
#  901: 'convocare',
#  902: '26',
#  903: 'doppio',
#  904: 'capire',
#  905: 'francia',
#  906: 'ripresa',
#  907: 'possibilità',
#  908: 'perdere',
#  909: 'esperienza',
#  910: 'riconoscere',
#  911: 'italmobiliare',
#  912: 'agenzia',
#  913: 'disponibile',
#  914: 'lato',
#  915: 'nascere',
#  916: 'tecnologico',
#  917: 'regione',
#  918: 'interamente',
#  919: 'internet',
#  920: 'economia',
#  921: 'cash',
#  922: 'conseguenza',
#  923: 'ipotesi',
#  924: '13_percento',
#  925: 'of',
#  926: 'luce',
#  927: 'credere',
#  928: 'tavolo',
#  929: 'posta',
#  930: 'f2i',
#  931: 'moretto',
#  932: 'pietro',
#  933: 'politica',
#  934: 'scegliere',
#  935: 'germania',
#  936: 'garanzia',
#  937: 'caratterizzare',
#  938: 'salino',
#  939: 'dimensione',
#  940: 'lusso',
#  941: 'ampio',
#  942: 'restante',
#  943: 'record',
#  944: 'coinvolgere',
#  945: 'riassetto',
#  946: 'fuori',
#  947: 'premio',
#  948: 'traffico',
#  949: 'promuovere',
#  950: 'ricorrere',
#  951: 'unire',
#  952: 'pirelli',
#  953: 'energy',
#  954: 'ferroviario',
#  955: 'obbligazionario',
#  956: 'autogrill',
#  957: 'comporre',
#  958: 'mostrare',
#  959: 'chiuso',
#  960: 'questione',
#  961: 'riguardo',
#  962: 'essere_crescere',
#  963: 'rafforzamento',
#  964: 'innovazione',
#  965: 'pur',
#  966: 'sindaco',
#  967: 'salinare',
#  968: 'ritorno',
#  969: 'membro',
#  970: 'trasmissione',
#  971: 'opas',
#  972: 'responsabile',
#  973: 'interessare',
#  974: 'notizia',
#  975: 'fca',
#  976: 'elemento',
#  977: 'tiscali',
#  978: 'evoluzione',
#  979: 'giapponese',
#  980: 'forza',
#  981: 'asia',
#  982: 'pieno',
#  983: 'informare',
#  984: 'petrolio',
#  985: 'riunire',
#  986: 'risparmiatore',
#  987: 'dedicare',
#  988: 'soddisfare',
#  989: 'considerazione',
#  990: 'sud',
#  991: 'installare',
#  992: 'conferma',
#  993: 'editore',
#  994: 'rinnovo',
#  995: 'mossa',
#  996: 'diretto',
#  997: 'vita',
#  998: '14_percento',
#  999: 'consumo',
#  ...}

# %%
num_points= 400
tsne= TSNE(perplexity=30, n_components= 2, init='pca', n_iter= 5000)
two_d_embeddings= tsne.fit_transform(model.wv.syn0[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(40,20)) # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
